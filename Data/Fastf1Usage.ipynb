# %% [markdown]
# Tester file to understand how to use fastf1

# %% [markdown]
# Plotting a speed trace

# %%
import fastf1
import fastf1.plotting
from matplotlib import pyplot as plt

fastf1.plotting.setup_mpl()

session = fastf1.get_session(2019, 'Monza', 'Q')
# print(session.event)
session.load()
fast_leclerc = session.laps.pick_driver('LEC').pick_fastest() #Picks fastest lap
lec_car_data = fast_leclerc.get_car_data()
# print(lec_car_data)
t = lec_car_data['Time']
vCar = lec_car_data['Speed']

#plotting
fig,ax = plt.subplots()
ax.plot(t,vCar, label = 'lec fastest lap')
ax.set_xlabel('Time')
ax.set_ylabel('Speed [kph]')
ax.set_title('LEC vCar Trace')
ax.legend()
plt.show()
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Qualifying [v3.3.8]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '77', '5', '3', '27', '55', '23', '18', '7', '99', '20', '26', '4', '10', '8', '11', '63', '88', '33']

# %% [markdown]
# Loading 7th event of qualifying in 2021

# %%
session = fastf1.get_session(2021, 7, 'Q') #7 denotes 7th race location (e.g. Le Castellet)
#session.event is subclass of pandas.Series object
#can also get session.event object directly as
event = fastf1.get_event(2021,7) #equivalent to session.event from session in line 1
#can also do
event = fastf1.get_event(2021, 'French Grand Prix')
#also don't need to specify exact name -- will find the best
event = fastf1.get_event(2021,'Spain')
#event['EventName'] = 'Spanish Grand Prix' not spain!! but not always accurate

# %% [markdown]
# Using full event schedule

# %%
Can also
